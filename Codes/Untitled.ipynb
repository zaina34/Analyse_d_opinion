# %% [markdown]
# # IMPORTATION DES LIBRARY

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from afinn import Afinn 
import spacy
from nltk.tokenize import sent_tokenize
from nltk.tokenize import word_tokenize
import re
from spacy.lang.fr.stop_words import STOP_WORDS
import string
from textblob import Blobber
from textblob_fr import PatternTagger, PatternAnalyzer
tb = Blobber(pos_tagger=PatternTagger(), analyzer=PatternAnalyzer())
import plotly.graph_objects as go
import plotly.express as px

# %%
dfparse = pd.read_excel("C://Users//ganci//Documents//master_miashs sans TER//Analyse de données textuelles//Projet//Analyse_d_opinion//Codes//ResultatsSpacy//data_bogda_Spacy.xlsx")
df = pd.read_csv("C://Users//ganci//Documents//master_miashs sans TER//Analyse de données textuelles//Projet//Analyse_d_opinion//Données//corpus_bogdanof.csv")
dfparse
# Out:
#        Unnamed: 0                  sujet  \
# 0               0  frerebogdanof_travaux
# 1               1  frerebogdanof_travaux
# 2               2  frerebogdanof_travaux
# 3               3  frerebogdanof_travaux
# 4               4  frerebogdanof_travaux
# ...           ...                    ...
# 42520       42520  frerebogdanof_travaux
# 42521       42521  frerebogdanof_travaux
# 42522       42522  frerebogdanof_travaux
# 42523       42523  frerebogdanof_travaux
# 42524       42524  frerebogdanof_travaux
#
#                                                tokenpost  \
# 0      ['pour', 'corriger', 'les', 'passages', 'tenda...
# 1      ['pour', 'corriger', 'les', 'passages', 'tenda...
# 2      ['pour', 'corriger', 'les', 'passages', 'tenda...
# 3      ['pour', 'corriger', 'les', 'passages', 'tenda...
# 4      ['pour', 'corriger', 'les', 'passages', 'tenda...
# ...                                                  ...
# 42520  ['une', 'série', 'de', 'vidéo', 'présentent', ...
# ...
